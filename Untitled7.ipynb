# %% [markdown]
# <a href="https://colab.research.google.com/github/ipriyanshuyadav21/apl_priyanshy/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
n = int(input())
days = list(range(1,n+1))
probabilities = []
p = 1

for i in range(365, 365-n, -1):
    p *= i / 365
    probabilities.append(p)

final_probablity =[365/365,365*364/(365*365),365*364*363/(365*365*365),(365*364*363*363)/(365*365*365*365),(365*364*363*362*361)/(365*365*365*365*365)]

plt.plot(days,probabilities)
plt.show()
# Out:
# 365
